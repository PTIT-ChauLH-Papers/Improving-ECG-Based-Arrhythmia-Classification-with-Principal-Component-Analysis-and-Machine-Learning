# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
variance = range(90,100, 1)
model = ['Ada_0_', 'DT_0_', 'KNN_0_', 'LR_0_', 'RF_0_', 'SVM_0_', 'XGB_0_']

# %% [markdown]
# ### Plot chart of Decision Tree

# %%
model[2][:-3]
# Out:
# 'KNN'

# %%
variance_list = list(variance)
labels = map(lambda x: str(x/100), variance_list)
print(variance_list)
print(list(labels))
# Out:
# [90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# ['0.9', '0.91', '0.92', '0.93', '0.94', '0.95', '0.96', '0.97', '0.98', '0.99']

# %%
variance = range(90,100, 1)
variance_list = list(variance)
labels = map(lambda x: str(x/100), variance_list)

for m in model:
    res_variance = []
    for v in variance_list:
        namefile = ('./Result/' + m + str(v) + '.csv')
        df_res = pd.read_csv(namefile)
        res_variance.append(df_res.iloc[:3, 2].mean())
    plt.plot(np.arange(0,len(list(variance))),res_variance, label=m[:-3])
    # plt.xlim()
plt.ylim([0.7, 1])
plt.xticks(np.arange(0,len(variance_list)), labels=list(labels))
plt.legend(loc="lower left", ncols=4)
plt.show()

# %%
df_res = pd.read_csv("./Result/Ada_0_90.csv")
df_res
# Out:
#    Unnamed: 0  Rhythm Group       ACC  F1-score  Precision    Recall  \
# 0           0          AFIB  0.909859  0.651685   0.886850  0.751295
# 1           1            SB  0.938498  0.955013   0.885578  0.918986
# 2           2            SR  0.945070  0.838202   0.892344  0.864426
# 3           3          GSVT  0.933333  0.937229   0.793040  0.859127
# 4           4     macro avg       NaN  0.848459   0.864453  0.845532
# 5           5     micro avg       NaN  0.863380   0.863380  0.863380
# 6           6  weighted avg       NaN  0.859570   0.867186  0.863380
#
#    specificity  Feature        Time
# 0     0.978042      NaN         NaN
# 1     0.928994      NaN         NaN
# 2     0.973294      NaN         NaN
# 3     0.932254      NaN         NaN
# 4     0.953146      NaN         NaN
# 5     0.954460      NaN         NaN
# 6     0.949203     51.0  123.006961

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Dữ liệu mẫu
model = ['Ada_0_', 'DT_0_', 'KNN_0_', 'LR_0_', 'RF_0_', 'SVM_0_', 'XGB_0_']

# Tạo ma trận dữ liệu để vẽ heatmap
heatmap_data = np.zeros((len(model), len(variance)))

for i, m in enumerate(model):
    for j, v in enumerate(variance):
        namefile = f'./Result/{m}{v}.csv'
        df_res = pd.read_csv(namefile)
        
        # Lấy giá trị micro avg
        heatmap_data[i, j] = df_res.iloc[:3, 2].mean()

# Tạo DataFrame cho dữ liệu heatmap
heatmap_df = pd.DataFrame(heatmap_data, columns=variance, index=model)

# Vẽ heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_df, annot=True, cmap='Blues', fmt='.2f', cbar_kws={'label': 'Micro Average'})
plt.title("Biểu đồ Heatmap - Micro Average")
plt.show()

# %%
import seaborn as sns

# Giả sử bạn đã có dữ liệu
model = ['Ada_0_', 'DT_0_', 'KNN_0_', 'LR_0_', 'RF_0_', 'SVM_0_', 'XGB_0_']

# Chuẩn bị dữ liệu cho boxplot
boxplot_data = []
model_labels = []

for m in model:
    for v in variance_list:
        namefile = f'./Result/{m}{v}.csv'
        df_res = pd.read_csv(namefile)
        
        # Lấy dữ liệu micro avg
        micro_avg = df_res.iloc[:3, 2].mean()
        boxplot_data.append(micro_avg)
        model_labels.append(m[:-3])  # Lưu tên mô hình

# Chuyển đổi thành DataFrame
df_boxplot = pd.DataFrame({'Model': model_labels, 'Micro Average': boxplot_data})

# Vẽ boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x="Model", y="Micro Average", data=df_boxplot)
plt.ylim([0.90, 1])
plt.title("Biểu đồ Boxplot - Micro Average")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

variance = range(90,100, 1)
variance_list = list(variance)
labels = map(lambda x: str(x/100), variance_list)
# Giả sử bạn có dữ liệu như trước
model = ['Ada_0_', 'DT_0_', 'KNN_0_', 'LR_0_', 'RF_0_', 'SVM_0_', 'XGB_0_']

for m in model:
    res_variance = []
    for v in variance:
        namefile = f'./Result/{m}{v}.csv'
        df_res = pd.read_csv(namefile)
        
        # Lấy giá trị micro avg từ cột thứ 3
        res_variance.append(df_res.iloc[:3, 2].mean())

    # Vẽ biểu đồ scatter
    plt.scatter(np.arange(0, len(variance_list)), res_variance, label=m[:-3])

plt.ylim([0.90, 1])
plt.xticks(np.arange(0, len(variance_list)), labels=labels)
plt.legend(loc="upper right", ncols=4)
plt.title("Biểu đồ Scatter - Micro Average")
plt.xlabel("Variance")
plt.ylabel("Micro Average")
plt.show()

# %%
# Dữ liệu giả định
variance = range(90,100, 1)
variance_list = list(variance)
labels = map(lambda x: str(x/100), variance_list)
model = ['Ada_0_', 'DT_0_', 'KNN_0_', 'LR_0_', 'RF_0_', 'SVM_0_', 'XGB_0_']

# Vẽ histogram cho mỗi mô hình
for m in model:
    res_variance = []
    for v in variance:
        namefile = f'./Result/{m}{v}.csv'
        df_res = pd.read_csv(namefile)
        
        # Lấy giá trị micro avg
        res_variance.append(df_res.iloc[:3, 2].mean())

    # Vẽ histogram cho dữ liệu
    plt.hist(res_variance, bins=5, alpha=0.7, label=m[:-3])

plt.xlabel("Micro Average")
plt.ylabel("Frequency")
plt.legend(loc="upper right", ncol=4)
plt.title("Biểu đồ Histogram - Micro Average")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Giả sử bạn có dữ liệu như trên
variance = range(90,100, 1)
variance_list = list(variance)
labels = map(lambda x: str(x/100), variance_list)
model = ['Ada_0_', 'DT_0_', 'KNN_0_', 'LR_0_', 'RF_0_', 'SVM_0_', 'XGB_0_']

# Tạo dữ liệu cho Stacked Bar
data = []

for m in model:
    res_variance = []
    for v in variance:
        namefile = f'./Result/{m}{v}.csv'
        df_res = pd.read_csv(namefile)
        
        # Lấy giá trị micro avg
        res_variance.append(df_res.iloc[:3, 2].mean())
    
    data.append(res_variance)

# Chuyển đổi dữ liệu thành mảng numpy
data = np.array(data)

# Vẽ Stacked Bar Chart với điều chỉnh khoảng cách cột
plt.figure(figsize=(10, 6))
bar_width = 0.4  # Đặt độ rộng của cột
index = np.arange(len(variance))  # Tạo mảng chỉ số cho trục x

# Vẽ cột cho mỗi mô hình với khoảng cách thích hợp
plt.bar(index, data[0], bar_width, label=model[0][:-3])
for i in range(1, len(model)):
    plt.bar(index, data[i], bar_width, bottom=data[:i].sum(axis=0), label=model[i][:-3])

# Đặt nhãn cho trục x
plt.xticks(index, variance)

# Thiết lập nhãn trục
plt.xlabel("Variance")
plt.ylabel("Micro Average")
plt.title("Biểu đồ Stacked Bar - Micro Average")
plt.ylim((0,8))
# Hiển thị legend
plt.legend(loc="upper left", ncol=4)

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()

# %%
variance = range(90,100, 1)
variance_list = list(variance)
labels = map(lambda x: str(x/100), variance_list)

for m in model:
    res_variance = []
    for v in variance:
        namefile = ('./Result/' + m + str(v) + '.csv')
        df_res = pd.read_csv(namefile)
        res_variance.append(df_res.iloc[5, 3])
    plt.plot(np.arange(0,len(variance_list)),res_variance, label=m[:-3])
    # plt.xlim()
plt.ylim([0.90, 1])
plt.xticks(np.arange(0,len(variance_list)), labels=labels)
plt.legend(loc="upper right", ncols=4)
plt.show()

# %%
df_res
# Out:
#    Unnamed: 0  Rhythm Group       ACC  F1-score  Precision    Recall  \
# 0           0          AFIB  0.964319  0.912360   0.916479  0.914414
# 1           1            SB  0.983099  0.987147   0.967254  0.977099
# 2           2            SR  0.976056  0.916854   0.966825  0.941176
# 3           3          GSVT  0.963850  0.926407   0.908705  0.917471
# 4           4     macro avg       NaN  0.937540   0.939816  0.935692
# 5           5     micro avg       NaN  0.943662   0.943662  0.943662
# 6           6  weighted avg       NaN  0.943565   0.943857  0.943662
#
#    specificity  Feature        Time
# 0     0.978042      NaN         NaN
# 1     0.980769      NaN         NaN
# 2     0.991691      NaN         NaN
# 3     0.974221      NaN         NaN
# 4     0.981181      NaN         NaN
# 5     0.981221      NaN         NaN
# 6     0.981061    138.0  347.178845

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

variance = range(90,100, 1)
variance_list = list(variance)
labels = map(lambda x: str(x/100), variance_list)
model = ['Ada_0_', 'DT_0_', 'KNN_0_', 'LR_0_', 'RF_0_', 'SVM_0_', 'XGB_0_']

for m in model:
    res_variance = []
    for v in variance:
        namefile = f'./Result/{m}{v}.csv'
        df_res = pd.read_csv(namefile)
        res_variance.append(df_res.iloc[5, 3])
    
    label_name = m[:-3]
    x = np.arange(len(variance))
    
    # Scatter points
    plt.scatter(x, res_variance, label=label_name)
    # Nối các điểm bằng đường line
    plt.plot(x, res_variance)

plt.ylim([0.5, 1])
plt.xticks(np.arange(len(variance)), labels=[f'{v}%' for v in variance])
plt.legend(loc="lower left", ncols=4)
plt.title("Accuracy average on tesing data")
plt.xlabel("Variance")
plt.ylabel("Accuracy average")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Dữ liệu mẫu
variance = range(90,100, 1)
variance_list = list(variance)
labels = map(lambda x: str(x/100), variance_list)

model = ['Ada_0_', 'DT_0_', 'KNN_0_', 'LR_0_', 'RF_0_', 'SVM_0_', 'XGB_0_']

# Tạo ma trận dữ liệu để vẽ heatmap
heatmap_data = np.zeros((len(model), len(variance)))

for i, m in enumerate(model):
    for j, v in enumerate(variance):
        namefile = f'./Result/{m}{v}.csv'
        df_res = pd.read_csv(namefile)
        
        # Lấy giá trị micro avg
        heatmap_data[i, j] = df_res.iloc[5, 3]

# Tạo DataFrame cho dữ liệu heatmap
heatmap_df = pd.DataFrame(heatmap_data, columns=variance, index=model)

# Vẽ heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_df, annot=True, cmap='Blues', fmt='.2f', cbar_kws={'label': 'Micro Average'})
plt.title("Biểu đồ Heatmap - Micro Average")
plt.show()

# %%
# Dữ liệu giả định
variance = range(90,100, 1)
variance_list = list(variance)
labels = map(lambda x: str(x/100), variance_list)
model = ['Ada_0_', 'DT_0_', 'KNN_0_', 'LR_0_', 'RF_0_', 'SVM_0_', 'XGB_0_']

# Vẽ histogram cho mỗi mô hình
for m in model:
    res_variance = []
    for v in variance:
        namefile = f'./Result/{m}{v}.csv'
        df_res = pd.read_csv(namefile)
        
        # Lấy giá trị micro avg
        res_variance.append(df_res.iloc[5, 3].mean())

    # Vẽ histogram cho dữ liệu
    plt.hist(res_variance, bins=5, alpha=0.7, label=m[:-3])

plt.xlabel("Micro Average")
plt.ylabel("Frequency")
plt.legend(loc="upper right", ncol=4)
plt.title("Biểu đồ Histogram - Micro Average")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Giả sử bạn có dữ liệu như trên
variance = range(90,100, 1)
variance_list = list(variance)
labels = map(lambda x: str(x/100), variance_list)
model = ['Ada_0_', 'DT_0_', 'KNN_0_', 'LR_0_', 'RF_0_', 'SVM_0_', 'XGB_0_']

# Tạo dữ liệu cho Stacked Bar
data = []

for m in model:
    res_variance = []
    for v in variance:
        namefile = f'./Result/{m}{v}.csv'
        df_res = pd.read_csv(namefile)
        
        # Lấy giá trị micro avg
        res_variance.append(df_res.iloc[5, 3])
    
    data.append(res_variance)

# Chuyển đổi dữ liệu thành mảng numpy
data = np.array(data)

# Vẽ Stacked Bar Chart với điều chỉnh khoảng cách cột
plt.figure(figsize=(10, 6))
bar_width = 0.4  # Đặt độ rộng của cột
index = np.arange(len(variance))  # Tạo mảng chỉ số cho trục x

# Vẽ cột cho mỗi mô hình với khoảng cách thích hợp
plt.bar(index, data[0], bar_width, label=model[0][:-3])
for i in range(1, len(model)):
    plt.bar(index, data[i], bar_width, bottom=data[:i].sum(axis=0), label=model[i][:-3])

# Đặt nhãn cho trục x
plt.xticks(index, variance)

# Thiết lập nhãn trục
plt.xlabel("Variance")
plt.ylabel("Micro Average")
plt.title("Biểu đồ Stacked Bar - Micro Average")
plt.ylim((0,8))
# Hiển thị legend
plt.legend(loc="upper left", ncol=4)

# Hiển thị biểu đồ
plt.tight_layout()
plt.show()

# %%
criteria = range(90,100,1)
print(list(criteria))
res = {'AFIB': 0, 'SB': 0, 'SR': 0, 'GSVT' : 0}
for number in criteria:
    df = pd.read_csv(f"./Result/DT_0_{number}.csv")
    res['AFIB'] += df.iloc[0,2]
    res['SB'] += df.iloc[1,2]
    res['SR'] += df.iloc[2,2]
    res['GSVT'] += df.iloc[3,2]

print((res['AFIB'] / len(criteria)) * 100)
print((res['SB'] / len(criteria)) * 100)
print((res['SR'] / len(criteria)) * 100)
print((res['GSVT'] / len(criteria)) * 100)
# Out:
# [90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# 84.25352112676056
# 87.99530516431923
# 82.74647887323944
# 85.27699530516432

# %%
criteria = range(90,100,1)
print(list(criteria))
res = {'AFIB': 0, 'SB': 0, 'SR': 0, 'GSVT' : 0}
for number in criteria:
    df = pd.read_csv(f"./Result/Ada_0_{number}.csv")
    res['AFIB'] += df.iloc[0,2]
    res['SB'] += df.iloc[1,2]
    res['SR'] += df.iloc[2,2]
    res['GSVT'] += df.iloc[3,2]

print((res['AFIB'] / len(criteria)) * 100)
print((res['SB'] / len(criteria)) * 100)
print((res['SR'] / len(criteria)) * 100)
print((res['GSVT'] / len(criteria)) * 100)
# Out:
# [90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# 90.98591549295776
# 93.84976525821595
# 94.50704225352113
# 93.33333333333333

# %%
criteria = range(90,100,1)
print(list(criteria))
res = {'AFIB': 0, 'SB': 0, 'SR': 0, 'GSVT' : 0}
for number in criteria:
    df = pd.read_csv(f"./Result/KNN_0_{number}.csv")
    res['AFIB'] += df.iloc[0,2]
    res['SB'] += df.iloc[1,2]
    res['SR'] += df.iloc[2,2]
    res['GSVT'] += df.iloc[3,2]

print((res['AFIB'] / len(criteria)) * 100)
print((res['SB'] / len(criteria)) * 100)
print((res['SR'] / len(criteria)) * 100)
print((res['GSVT'] / len(criteria)) * 100)
# Out:
# [90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# 94.9906103286385
# 97.37558685446007
# 96.2582159624413
# 94.96244131455398

# %%
criteria = range(90,100,1)
print(list(criteria))
res = {'AFIB': 0, 'SB': 0, 'SR': 0, 'GSVT' : 0}
for number in criteria:
    df = pd.read_csv(f"./Result/LR_0_{number}.csv")
    res['AFIB'] += df.iloc[0,2]
    res['SB'] += df.iloc[1,2]
    res['SR'] += df.iloc[2,2]
    res['GSVT'] += df.iloc[3,2]

print((res['AFIB'] / len(criteria)) * 100)
print((res['SB'] / len(criteria)) * 100)
print((res['SR'] / len(criteria)) * 100)
print((res['GSVT'] / len(criteria)) * 100)
# Out:
# [90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# 94.91079812206571
# 97.37089201877932
# 96.20657276995304
# 94.7230046948357

# %%
criteria = range(90,100,1)
print(list(criteria))
res = {'AFIB': 0, 'SB': 0, 'SR': 0, 'GSVT' : 0}
for number in criteria:
    df = pd.read_csv(f"./Result/RF_0_{number}.csv")
    res['AFIB'] += df.iloc[0,2]
    res['SB'] += df.iloc[1,2]
    res['SR'] += df.iloc[2,2]
    res['GSVT'] += df.iloc[3,2]

print((res['AFIB'] / len(criteria)) * 100)
print((res['SB'] / len(criteria)) * 100)
print((res['SR'] / len(criteria)) * 100)
print((res['GSVT'] / len(criteria)) * 100)
# Out:
# [90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# 95.10798122065725
# 97.60563380281691
# 96.6244131455399
# 95.55399061032863

# %%
criteria = range(90,100,1)
print(list(criteria))
res = {'AFIB': 0, 'SB': 0, 'SR': 0, 'GSVT' : 0}
for number in criteria:
    df = pd.read_csv(f"./Result/SVM_0_{number}.csv")
    res['AFIB'] += df.iloc[0,2]
    res['SB'] += df.iloc[1,2]
    res['SR'] += df.iloc[2,2]
    res['GSVT'] += df.iloc[3,2]

print((res['AFIB'] / len(criteria)) * 100)
print((res['SB'] / len(criteria)) * 100)
print((res['SR'] / len(criteria)) * 100)
print((res['GSVT'] / len(criteria)) * 100)
# Out:
# [90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# 96.65258215962442
# 98.58215962441314
# 97.92488262910798
# 96.49295774647888

# %%
criteria = range(90,100,1)
print(list(criteria))
res = {'AFIB': 0, 'SB': 0, 'SR': 0, 'GSVT' : 0}
for number in criteria:
    df = pd.read_csv(f"./Result/XGB_0_{number}.csv")
    res['AFIB'] += df.iloc[0,2]
    res['SB'] += df.iloc[1,2]
    res['SR'] += df.iloc[2,2]
    res['GSVT'] += df.iloc[3,2]

print((res['AFIB'] / len(criteria)) * 100)
print((res['SB'] / len(criteria)) * 100)
print((res['SR'] / len(criteria)) * 100)
print((res['GSVT'] / len(criteria)) * 100)
# Out:
# [90, 91, 92, 93, 94, 95, 96, 97, 98, 99]
# 96.28169014084506
# 98.1924882629108
# 97.4600938967136
# 96.29107981220658
