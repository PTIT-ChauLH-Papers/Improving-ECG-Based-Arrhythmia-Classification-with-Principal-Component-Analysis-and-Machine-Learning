# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# %%
df_train = pd.read_csv("./dataset/data_train_frequency.csv")
df_train.drop(columns=["Unnamed: 0"],inplace=True)

# %%
x_train = df_train.iloc[:,1:].values
y_train = df_train.iloc[:,0].values

# %%
df_test = pd.read_csv("./dataset/data_test_frequency.csv")
df_test.drop(columns=["Unnamed: 0"],inplace=True)

# %%
x_test = df_test.iloc[:,1:].values
y_test = df_test.iloc[:,0].values

# %%
var_pca = [i/100 for i in range(90,101)]
res_timerun = []

# %%
for var in var_pca:
    scale = MinMaxScaler()
    x_train_sc = scale.fit_transform(x_train)

    pca = PCA(n_components=var)
    x_train_pca = pca.fit_transform(x_train_sc)
    d_train = x_train_pca.shape[1]

    x_test_sc = scale.transform(x_test)
    x_test_pca = pca.transform(x_test_sc)

    import time
    start_time = time.perf_counter()

    from sklearn.ensemble import AdaBoostClassifier
    from sklearn.model_selection import GridSearchCV
    model = AdaBoostClassifier()
    
    params = {
        'n_estimators': [59,60,61],
        'learning_rate': [0.075, 0.1, 0.125],
        'algorithm': ['SAMME', 'SAMME.R'],
    }
    grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
    grid_model = grid_search.fit(x_train_pca,y_train)

    end_time = time.perf_counter()
    res_etime = end_time - start_time
    res_timerun.append(res_etime)
    
    result_test = grid_model.predict(x_test_pca)
    result_train = grid_model.predict_proba(x_train_pca)
    from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,multilabel_confusion_matrix,f1_score,precision_score,accuracy_score,recall_score,precision_recall_fscore_support
    def evaluation_test(y,y_pred, time):
        cm = confusion_matrix(y,y_pred)
        disp = ConfusionMatrixDisplay(cm,display_labels=['AFIB','SB','SR','GSVT'])
        disp.plot()
        plt.show()
        n_classes = len(cm)
        class_counts = np.sum(cm, axis=1)
        result = []
        specificities = []
        weights = class_counts / np.sum(class_counts) 
        for c in range(n_classes):
            tp = cm[c,c]
            fp = sum(cm[:,c]) - cm[c,c]
            fn = sum(cm[c,:]) - cm[c,c]
            tn = sum(np.delete(sum(cm)-cm[c,:],c))
            acc = (tp+tn) / (tp+fn+tn+fp)
            recall = tp/(tp+fn)
            precision = tp/(tp+fp)
            specificity = tn/(tn+fp)
            specificities.append(specificity)
            f1_score = 2*((precision*recall)/(precision+recall))
            if c+1 == 1:
                Rhythm = 'AFIB'
            elif c+1 == 2:
                Rhythm = 'SB'
            elif c+1 == 3:
                Rhythm = 'SR'
            else:
                Rhythm = 'GSVT'
            result.append([Rhythm,acc,recall,precision,f1_score,specificity])
        p_macro,r_macro,f_macro,support_macro = precision_recall_fscore_support(y,y_pred,average='macro')
        p_micro,r_micro,f_micro,support_micro = precision_recall_fscore_support(y,y_pred,average='micro')
        p_weighted,r_weighted,f_weighted,support_weighted = precision_recall_fscore_support(y,y_pred,average='weighted')

        s_marco = np.mean(specificities)
        tn_total = np.sum([np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1)) for i in range(n_classes)])
        fp_total = np.sum([np.sum(cm[:, i]) - cm[i, i] for i in range(n_classes)])
        s_mirco = tn_total / (tn_total + fp_total)
        s_weighted = np.sum(weights * specificities)

        result.append(['macro avg',None,f_macro,p_macro,r_macro,s_marco])
        result.append(['micro avg',None,f_micro,p_micro,r_micro,s_mirco])
        result.append(['weighted avg',None,f_weighted,p_weighted,r_weighted,s_weighted, d_train, time])
        return result
    evaluation_test = evaluation_test(y_test, result_test, res_etime)
    df_evaluation_test = pd.DataFrame(data=evaluation_test,columns=["Rhythm Group","ACC","F1-score","Precision","Recall","specificity","Feature", "Time"])
    var_text = str(var).replace('.','_')
    df_evaluation_test.to_csv(f"./Result/Ada_{var_text}.csv")
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.822, test=0.816) total time=   1.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.819, test=0.820) total time=   1.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.817, test=0.811) total time=   1.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.823, test=0.816) total time=   1.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.816, test=0.816) total time=   1.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.815, test=0.806) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.822, test=0.816) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.816, test=0.816) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.817, test=0.810) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.824, test=0.817) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.820, test=0.822) total time=   1.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.818, test=0.809) total time=   1.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.822, test=0.817) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.819, test=0.820) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.814, test=0.804) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.824, test=0.817) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.821, test=0.821) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.818, test=0.810) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.824, test=0.822) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.821, test=0.822) total time=   1.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.854, test=0.838) total time=   1.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.847, test=0.851) total time=   1.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.821, test=0.821) total time=   1.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.824, test=0.814) total time=   1.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.850, test=0.854) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.838, test=0.840) total time=   1.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.825, test=0.816) total time=   1.7s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 27 fits failed out of a total of 54.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 27 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'algorithm' parameter of AdaBoostClassifier must be a str among {'SAMME'}. Got 'SAMME.R' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.81552316 0.81258728 0.81399676 0.81587515 0.81376124 0.8161101
#  0.82726753 0.82890857 0.83665794        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the train scores are non-finite: [0.81934019 0.81804855 0.8186943  0.82069062 0.81857704 0.82121905
#  0.83331253 0.83067204 0.83783542        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.822, test=0.816) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.819, test=0.820) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.817, test=0.811) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.823, test=0.816) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.816, test=0.816) total time=   2.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.815, test=0.806) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.822, test=0.816) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.816, test=0.816) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.817, test=0.810) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.824, test=0.817) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.820, test=0.822) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.818, test=0.809) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.822, test=0.817) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.819, test=0.820) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.814, test=0.804) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.824, test=0.817) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.821, test=0.821) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.818, test=0.810) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.824, test=0.822) total time=   2.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.821, test=0.822) total time=   2.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.854, test=0.838) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.847, test=0.851) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.821, test=0.821) total time=   1.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.824, test=0.814) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.850, test=0.854) total time=   1.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.838, test=0.840) total time=   2.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.825, test=0.816) total time=   1.9s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 27 fits failed out of a total of 54.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 27 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'algorithm' parameter of AdaBoostClassifier must be a str among {'SAMME'}. Got 'SAMME.R' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.81552316 0.81258728 0.81399676 0.81587515 0.81376124 0.8161101
#  0.82726753 0.82890857 0.83665794        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the train scores are non-finite: [0.81934019 0.81804855 0.8186943  0.82069062 0.81857704 0.82121905
#  0.83331253 0.83067204 0.83783542        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.822, test=0.816) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.819, test=0.820) total time=   2.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.817, test=0.811) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.823, test=0.816) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.816, test=0.816) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.815, test=0.806) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.822, test=0.816) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.816, test=0.816) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.817, test=0.810) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.824, test=0.817) total time=   2.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.820, test=0.822) total time=   2.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.818, test=0.809) total time=   2.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.822, test=0.817) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.819, test=0.820) total time=   2.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.814, test=0.804) total time=   2.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.824, test=0.817) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.821, test=0.821) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.818, test=0.810) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.824, test=0.822) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.821, test=0.822) total time=   2.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.854, test=0.838) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.847, test=0.851) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.821, test=0.821) total time=   2.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.824, test=0.814) total time=   2.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.850, test=0.854) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.838, test=0.840) total time=   2.1s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.825, test=0.816) total time=   2.1s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 27 fits failed out of a total of 54.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 27 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'algorithm' parameter of AdaBoostClassifier must be a str among {'SAMME'}. Got 'SAMME.R' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.81552316 0.81258728 0.81399676 0.81587515 0.81376124 0.8161101
#  0.82726753 0.82890857 0.83665794        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the train scores are non-finite: [0.81934019 0.81804855 0.8186943  0.82069062 0.81857704 0.82121905
#  0.83331253 0.83067204 0.83783542        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.822, test=0.816) total time=   2.2s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.819, test=0.820) total time=   2.2s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.817, test=0.811) total time=   2.2s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.823, test=0.816) total time=   2.2s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.816, test=0.816) total time=   2.2s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.815, test=0.806) total time=   2.2s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.822, test=0.816) total time=   2.3s
# ...
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.815, test=0.806) total time=   4.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.822, test=0.816) total time=   4.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.816, test=0.816) total time=   4.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.817, test=0.810) total time=   4.6s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.824, test=0.817) total time=   4.4s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.820, test=0.822) total time=   4.5s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.818, test=0.809) total time=   4.6s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.822, test=0.817) total time=   4.6s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.819, test=0.820) total time=   4.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.814, test=0.804) total time=   4.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.824, test=0.817) total time=   4.6s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.821, test=0.821) total time=   4.9s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.818, test=0.810) total time=   4.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.824, test=0.822) total time=   4.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.821, test=0.822) total time=   4.6s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.854, test=0.838) total time=   4.5s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.847, test=0.851) total time=   4.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.821, test=0.821) total time=   4.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.824, test=0.814) total time=   4.7s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.850, test=0.854) total time=   4.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.838, test=0.840) total time=   4.8s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.825, test=0.816) total time=   4.8s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 27 fits failed out of a total of 54.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 27 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'algorithm' parameter of AdaBoostClassifier must be a str among {'SAMME'}. Got 'SAMME.R' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.81552316 0.81258728 0.81399676 0.81587515 0.81376124 0.8161101
#  0.82726753 0.82890857 0.83665794        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the train scores are non-finite: [0.81934019 0.81804855 0.8186943  0.82069062 0.81857704 0.82121905
#  0.83331253 0.83067204 0.83783542        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# /Users/camnh/Library/Python/3.9/lib/python/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[10], line 6
#       3 x_train_sc = scale.fit_transform(x_train)
#       5 pca = PCA(n_components=var)
# ----> 6 x_train_pca = pca.fit_transform(x_train_sc)
#       7 d_train = x_train_pca.shape[1]
#       9 x_test_sc = scale.transform(x_test)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:1382, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1377 partial_fit_and_fitted = (
#    1378     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1379 )
#    1381 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
#    1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:436, in BaseEstimator._validate_params(self)
#     428 def _validate_params(self):
#     429     """Validate types and values of constructor parameters
#     430
#     431     The expected type and values must be defined in the `_parameter_constraints`
#    (...)
#     434     accepted constraints.
#     435     """
# --> 436     validate_parameter_constraints(
#     437         self._parameter_constraints,
#     438         self.get_params(deep=False),
#     439         caller_name=self.__class__.__name__,
#     440     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_param_validation.py:98, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      92 else:
#      93     constraints_str = (
#      94         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      95         f" {constraints[-1]}"
#      96     )
# ---> 98 raise InvalidParameterError(
#      99     f"The {param_name!r} parameter of {caller_name} must be"
#     100     f" {constraints_str}. Got {param_val!r} instead."
#     101 )
#
# InvalidParameterError: The 'n_components' parameter of PCA must be an int in the range [0, inf), a float in the range (0.0, 1.0), a str among {'mle'} or None. Got 1.0 instead.

# %% [markdown]
# 0.99 -> 138
# 0.98 -> 116
# 0.96 -> 90
# 0.95 -> 81
# 0.90 -> 51
