# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# %%
df_train = pd.read_csv("./dataset/data_train_frequency.csv")
df_train.drop(columns=["Unnamed: 0"],inplace=True)

# %%
x_train = df_train.iloc[:,1:].values
y_train = df_train.iloc[:,0].values

# %%
df_test = pd.read_csv("./dataset/data_test_frequency.csv")
df_test.drop(columns=["Unnamed: 0"],inplace=True)

# %%
x_test = df_test.iloc[:,1:].values
y_test = df_test.iloc[:,0].values

# %%
var_pca = [float(i/100) for i in range(90,101)]
res_timerun = []

# %%
for var in var_pca:
    scale = MinMaxScaler()
    x_train_sc = scale.fit_transform(x_train)

    pca = PCA(n_components=var)
    x_train_pca = pca.fit_transform(x_train_sc)
    d_train = x_train_pca.shape[1]

    x_test_sc = scale.transform(x_test)
    x_test_pca = pca.transform(x_test_sc)

    import time
    start_time = time.perf_counter()

    from sklearn.ensemble import AdaBoostClassifier
    from sklearn.model_selection import GridSearchCV
    model = AdaBoostClassifier()
    
    params = {
        'n_estimators': [59,60,61],
        'learning_rate': [0.075, 0.1, 0.125],
        'algorithm': ['SAMME', 'SAMME.R'],
    }
    grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
    grid_model = grid_search.fit(x_train_pca,y_train)

    end_time = time.perf_counter()
    res_etime = end_time - start_time
    res_timerun.append(res_etime)
    
    result_test = grid_model.predict(x_test_pca)
    result_train = grid_model.predict_proba(x_train_pca)
    from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,multilabel_confusion_matrix,f1_score,precision_score,accuracy_score,recall_score,precision_recall_fscore_support
    def evaluation_test(y,y_pred, time):
        cm = confusion_matrix(y,y_pred)
        disp = ConfusionMatrixDisplay(cm,display_labels=['AFIB','SB','SR','GSVT'])
        disp.plot()
        plt.show()
        n_classes = len(cm)
        class_counts = np.sum(cm, axis=1)
        result = []
        specificities = []
        weights = class_counts / np.sum(class_counts) 
        for c in range(n_classes):
            tp = cm[c,c]
            fp = sum(cm[:,c]) - cm[c,c]
            fn = sum(cm[c,:]) - cm[c,c]
            tn = sum(np.delete(sum(cm)-cm[c,:],c))
            acc = (tp+tn) / (tp+fn+tn+fp)
            recall = tp/(tp+fn)
            precision = tp/(tp+fp)
            specificity = tn/(tn+fp)
            specificities.append(specificity)
            f1_score = 2*((precision*recall)/(precision+recall))
            if c+1 == 1:
                Rhythm = 'AFIB'
            elif c+1 == 2:
                Rhythm = 'SB'
            elif c+1 == 3:
                Rhythm = 'SR'
            else:
                Rhythm = 'GSVT'
            result.append([Rhythm,acc,recall,precision,f1_score,specificity])
        p_macro,r_macro,f_macro,support_macro = precision_recall_fscore_support(y,y_pred,average='macro')
        p_micro,r_micro,f_micro,support_micro = precision_recall_fscore_support(y,y_pred,average='micro')
        p_weighted,r_weighted,f_weighted,support_weighted = precision_recall_fscore_support(y,y_pred,average='weighted')

        s_marco = np.mean(specificities)
        tn_total = np.sum([np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1)) for i in range(n_classes)])
        fp_total = np.sum([np.sum(cm[:, i]) - cm[i, i] for i in range(n_classes)])
        s_mirco = tn_total / (tn_total + fp_total)
        s_weighted = np.sum(weights * specificities)

        result.append(['macro avg',None,f_macro,p_macro,r_macro,s_marco])
        result.append(['micro avg',None,f_micro,p_micro,r_micro,s_mirco])
        result.append(['weighted avg',None,f_weighted,p_weighted,r_weighted,s_weighted, d_train, time])
        return result
    evaluation_test = evaluation_test(y_test, result_test, res_etime)
    df_evaluation_test = pd.DataFrame(data=evaluation_test,columns=["Rhythm Group","ACC","F1-score","Precision","Recall","specificity","Feature", "Time"])
    var_text = str(var).replace('.','_')
    df_evaluation_test.to_csv(f"./Result/Ada_{var_text}.csv")
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.822, test=0.816) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.819, test=0.820) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.817, test=0.811) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.823, test=0.816) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.816, test=0.816) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.815, test=0.806) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.822, test=0.816) total time=   2.1s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.816, test=0.816) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.817, test=0.810) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.824, test=0.817) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.820, test=0.822) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.818, test=0.809) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.822, test=0.817) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.819, test=0.820) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.814, test=0.804) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.824, test=0.817) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.821, test=0.821) total time=   2.1s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.818, test=0.810) total time=   2.1s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.824, test=0.822) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.821, test=0.822) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.854, test=0.838) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.847, test=0.851) total time=   2.1s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.821, test=0.821) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.824, test=0.814) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.850, test=0.854) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.838, test=0.840) total time=   2.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.825, test=0.816) total time=   2.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 27 fits failed out of a total of 54.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 27 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'algorithm' parameter of AdaBoostClassifier must be a str among {'SAMME'}. Got 'SAMME.R' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.81552316 0.81258728 0.81399676 0.81587515 0.81376124 0.8161101
#  0.82726753 0.82890857 0.83665794        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the train scores are non-finite: [0.81934019 0.81804855 0.8186943  0.82069062 0.81857704 0.82121905
#  0.83331253 0.83067204 0.83783542        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.822, test=0.816) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.819, test=0.820) total time=   2.1s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.817, test=0.811) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.823, test=0.816) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.816, test=0.816) total time=   2.3s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.815, test=0.806) total time=   2.3s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.822, test=0.816) total time=   2.3s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.816, test=0.816) total time=   2.3s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.817, test=0.810) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.824, test=0.817) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.820, test=0.822) total time=   2.1s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.818, test=0.809) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.822, test=0.817) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.819, test=0.820) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.814, test=0.804) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.824, test=0.817) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.821, test=0.821) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.818, test=0.810) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.824, test=0.822) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.821, test=0.822) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.854, test=0.838) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.847, test=0.851) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.821, test=0.821) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.824, test=0.814) total time=   2.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.850, test=0.854) total time=   2.3s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.838, test=0.840) total time=   2.3s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.825, test=0.816) total time=   2.3s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 27 fits failed out of a total of 54.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 27 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'algorithm' parameter of AdaBoostClassifier must be a str among {'SAMME'}. Got 'SAMME.R' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.81552316 0.81258728 0.81399676 0.81587515 0.81376124 0.8161101
#  0.82726753 0.82890857 0.83665794        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the train scores are non-finite: [0.81934019 0.81804855 0.8186943  0.82069062 0.81857704 0.82121905
#  0.83331253 0.83067204 0.83783542        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.822, test=0.816) total time=   2.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.819, test=0.820) total time=   2.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.817, test=0.811) total time=   2.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.823, test=0.816) total time=   2.6s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.816, test=0.816) total time=   2.7s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.815, test=0.806) total time=   2.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.822, test=0.816) total time=   2.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.816, test=0.816) total time=   2.5s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.817, test=0.810) total time=   2.5s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.824, test=0.817) total time=   2.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.820, test=0.822) total time=   2.5s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.818, test=0.809) total time=   2.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.822, test=0.817) total time=   2.5s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.819, test=0.820) total time=   2.5s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.814, test=0.804) total time=   2.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.824, test=0.817) total time=   2.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.821, test=0.821) total time=   2.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.818, test=0.810) total time=   2.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.824, test=0.822) total time=   2.3s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.821, test=0.822) total time=   2.3s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.854, test=0.838) total time=   2.3s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.847, test=0.851) total time=   2.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.821, test=0.821) total time=   2.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.824, test=0.814) total time=   2.3s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.850, test=0.854) total time=   2.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.838, test=0.840) total time=   2.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.825, test=0.816) total time=   2.4s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 27 fits failed out of a total of 54.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 27 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'algorithm' parameter of AdaBoostClassifier must be a str among {'SAMME'}. Got 'SAMME.R' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.81552316 0.81258728 0.81399676 0.81587515 0.81376124 0.8161101
#  0.82726753 0.82890857 0.83665794        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the train scores are non-finite: [0.81934019 0.81804855 0.8186943  0.82069062 0.81857704 0.82121905
#  0.83331253 0.83067204 0.83783542        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.822, test=0.816) total time=   2.6s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.819, test=0.820) total time=   2.6s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# ...
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.822, test=0.816) total time=   4.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.816, test=0.816) total time=   4.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.817, test=0.810) total time=   4.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.824, test=0.817) total time=   4.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.820, test=0.822) total time=   4.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.818, test=0.809) total time=   4.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.822, test=0.817) total time=   4.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.819, test=0.820) total time=   4.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.814, test=0.804) total time=   4.1s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.824, test=0.817) total time=   4.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.821, test=0.821) total time=   4.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.818, test=0.810) total time=   4.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.824, test=0.822) total time=   4.3s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.821, test=0.822) total time=   4.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.854, test=0.838) total time=   4.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.847, test=0.851) total time=   4.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.821, test=0.821) total time=   4.3s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.824, test=0.814) total time=   4.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.850, test=0.854) total time=   4.3s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 25
#      19 params = {
#      20     'n_estimators': [59,60,61],
#      21     'learning_rate': [0.075, 0.1, 0.125],
#      22     'algorithm': ['SAMME', 'SAMME.R'],
#      23 }
#      24 grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
# ---> 25 grid_model = grid_search.fit(x_train_pca,y_train)
#      27 end_time = time.perf_counter()
#      28 res_etime = end_time - start_time
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:1024, in BaseSearchCV.fit(self, X, y, **params)
#    1018     results = self._format_results(
#    1019         all_candidate_params, n_splits, all_out, all_more_results
#    1020     )
#    1022     return results
# -> 1024 self._run_search(evaluate_candidates)
#    1026 # multimetric is determined here because in the case of a callable
#    1027 # self.scoring the return type is only known after calling
#    1028 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:1571, in GridSearchCV._run_search(self, evaluate_candidates)
#    1569 def _run_search(self, evaluate_candidates):
#    1570     """Search all candidates in param_grid"""
# -> 1571     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:970, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     962 if self.verbose > 0:
#     963     print(
#     964         "Fitting {0} folds for each of {1} candidates,"
#     965         " totalling {2} fits".format(
#     966             n_splits, n_candidates, n_candidates * n_splits
#     967         )
#     968     )
# --> 970 out = parallel(
#     971     delayed(_fit_and_score)(
#     972         clone(base_estimator),
#     973         X,
#     974         y,
#     975         train=train,
#     976         test=test,
#     977         parameters=parameters,
#     978         split_progress=(split_idx, n_splits),
#     979         candidate_progress=(cand_idx, n_candidates),
#     980         **fit_and_score_kwargs,
#     981     )
#     982     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     983         enumerate(candidate_params),
#     984         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     985     )
#     986 )
#     988 if len(out) < 1:
#     989     raise ValueError(
#     990         "No fits were performed. "
#     991         "Was the CV iterator empty? "
#     992         "Were there no candidates?"
#     993     )
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:866, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     864         estimator.fit(X_train, **fit_params)
#     865     else:
# --> 866         estimator.fit(X_train, y_train, **fit_params)
#     868 except Exception:
#     869     # Note fit time as time until error
#     870     fit_time = time.time() - start_time
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:167, in BaseWeightBoosting.fit(self, X, y, sample_weight)
#     164 sample_weight[zero_weight_mask] = 0.0
#     166 # Boosting step
# --> 167 sample_weight, estimator_weight, estimator_error = self._boost(
#     168     iboost, X, y, sample_weight, random_state
#     169 )
#     171 # Early termination
#     172 if sample_weight is None:
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:570, in AdaBoostClassifier._boost(self, iboost, X, y, sample_weight, random_state)
#     531 """Implement a single boost.
#     532
#     533 Perform a single boost according to the discrete SAMME algorithm and return the
#    (...)
#     566     If None then boosting has terminated early.
#     567 """
#     568 estimator = self._make_estimator(random_state=random_state)
# --> 570 estimator.fit(X, y, sample_weight=sample_weight)
#     572 y_predict = estimator.predict(X)
#     574 if iboost == 0:
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py:1024, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     993 @_fit_context(prefer_skip_nested_validation=True)
#     994 def fit(self, X, y, sample_weight=None, check_input=True):
#     995     """Build a decision tree classifier from the training set (X, y).
#     996
#     997     Parameters
#    (...)
#    1021         Fitted estimator.
#    1022     """
# -> 1024     super()._fit(
#    1025         X,
#    1026         y,
#    1027         sample_weight=sample_weight,
#    1028         check_input=check_input,
#    1029     )
#    1030     return self
#
# File c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
scale = MinMaxScaler()
x_train_sc = scale.fit_transform(x_train)

pca = PCA(n_components=None)
x_train_pca = pca.fit_transform(x_train_sc)
d_train = x_train_pca.shape[1]

x_test_sc = scale.transform(x_test)
x_test_pca = pca.transform(x_test_sc)

import time
start_time = time.perf_counter()

from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
model = AdaBoostClassifier()

params = {
    'n_estimators': [59,60,61],
    'learning_rate': [0.075, 0.1, 0.125],
    'algorithm': ['SAMME', 'SAMME.R'],
}
grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
grid_model = grid_search.fit(x_train_pca,y_train)

end_time = time.perf_counter()
result_test = grid_model.predict(x_test_pca)
result_train = grid_model.predict_proba(x_train_pca)
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,multilabel_confusion_matrix,f1_score,precision_score,accuracy_score,recall_score,precision_recall_fscore_support
def evaluation_test(y,y_pred, time):
    cm = confusion_matrix(y,y_pred)
    disp = ConfusionMatrixDisplay(cm,display_labels=['AFIB','SB','SR','GSVT'])
    disp.plot()
    plt.show()
    n_classes = len(cm)
    class_counts = np.sum(cm, axis=1)
    result = []
    specificities = []
    weights = class_counts / np.sum(class_counts) 
    for c in range(n_classes):
        tp = cm[c,c]
        fp = sum(cm[:,c]) - cm[c,c]
        fn = sum(cm[c,:]) - cm[c,c]
        tn = sum(np.delete(sum(cm)-cm[c,:],c))
        acc = (tp+tn) / (tp+fn+tn+fp)
        recall = tp/(tp+fn)
        precision = tp/(tp+fp)
        specificity = tn/(tn+fp)
        specificities.append(specificity)
        f1_score = 2*((precision*recall)/(precision+recall))
        if c+1 == 1:
            Rhythm = 'AFIB'
        elif c+1 == 2:
            Rhythm = 'SB'
        elif c+1 == 3:
            Rhythm = 'SR'
        else:
            Rhythm = 'GSVT'
        result.append([Rhythm,acc,recall,precision,f1_score,specificity])
    p_macro,r_macro,f_macro,support_macro = precision_recall_fscore_support(y,y_pred,average='macro')
    p_micro,r_micro,f_micro,support_micro = precision_recall_fscore_support(y,y_pred,average='micro')
    p_weighted,r_weighted,f_weighted,support_weighted = precision_recall_fscore_support(y,y_pred,average='weighted')

    s_marco = np.mean(specificities)
    tn_total = np.sum([np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1)) for i in range(n_classes)])
    fp_total = np.sum([np.sum(cm[:, i]) - cm[i, i] for i in range(n_classes)])
    s_mirco = tn_total / (tn_total + fp_total)
    s_weighted = np.sum(weights * specificities)

    result.append(['macro avg',None,f_macro,p_macro,r_macro,s_marco])
    result.append(['micro avg',None,f_micro,p_micro,r_micro,s_mirco])
    result.append(['weighted avg',None,f_weighted,p_weighted,r_weighted,s_weighted, d_train, time])
    return result
evaluation_test = evaluation_test(y_test, result_test, res_etime)
df_evaluation_test = pd.DataFrame(data=evaluation_test,columns=["Rhythm Group","ACC","F1-score","Precision","Recall","specificity","Feature", "Time"])
df_evaluation_test.to_csv(f"./Result/Ada_0_100.csv")
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.822, test=0.816) total time=   8.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.819, test=0.820) total time=   8.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=59;, score=(train=0.817, test=0.811) total time=   8.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.823, test=0.816) total time=   9.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.816, test=0.816) total time=   8.5s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=60;, score=(train=0.815, test=0.806) total time=   8.6s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.822, test=0.816) total time=   8.6s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.816, test=0.816) total time=   8.7s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.075, n_estimators=61;, score=(train=0.817, test=0.810) total time=   8.8s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.824, test=0.817) total time=   8.4s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.820, test=0.822) total time=   8.6s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=59;, score=(train=0.818, test=0.809) total time=   8.5s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.822, test=0.817) total time=   8.6s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.819, test=0.820) total time=   8.6s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=60;, score=(train=0.814, test=0.804) total time=   8.7s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.824, test=0.817) total time=  10.1s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.821, test=0.821) total time=  10.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.1, n_estimators=61;, score=(train=0.818, test=0.810) total time=  10.1s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.824, test=0.822) total time=   9.8s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.821, test=0.822) total time=   9.8s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=59;, score=(train=0.854, test=0.838) total time=   9.7s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.847, test=0.851) total time=   9.9s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.821, test=0.821) total time=  10.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=60;, score=(train=0.824, test=0.814) total time=   9.9s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 1/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.850, test=0.854) total time=  10.1s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 2/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.838, test=0.840) total time=  10.2s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(
# [CV 3/3] END algorithm=SAMME, learning_rate=0.125, n_estimators=61;, score=(train=0.825, test=0.816) total time=  10.1s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.075, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.1, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=59;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=60;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END algorithm=SAMME.R, learning_rate=0.125, n_estimators=61;, score=(train=nan, test=nan) total time=   0.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 27 fits failed out of a total of 54.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 27 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'algorithm' parameter of AdaBoostClassifier must be a str among {'SAMME'}. Got 'SAMME.R' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.81552316 0.81258728 0.81399676 0.81587515 0.81376124 0.8161101
#  0.82726753 0.82890857 0.83665794        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the train scores are non-finite: [0.81934019 0.81804855 0.8186943  0.82069062 0.81857704 0.82121905
#  0.83331253 0.83067204 0.83783542        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The parameter 'algorithm' is deprecated in 1.6 and has no effect. It will be removed in version 1.8.
#   warnings.warn(

# %% [markdown]
# 0.99 -> 138
# 0.98 -> 116
# 0.96 -> 90
# 0.95 -> 81
# 0.90 -> 51
