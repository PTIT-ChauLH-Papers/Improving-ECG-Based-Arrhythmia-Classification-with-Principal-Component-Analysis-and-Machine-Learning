# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# %%
df_train = pd.read_csv("./dataset/data_train_frequency.csv")
df_train.drop(columns=["Unnamed: 0"],inplace=True)

# %%
x_train = df_train.iloc[:,1:].values
y_train = df_train.iloc[:,0].values

# %%
df_test = pd.read_csv("./dataset/data_test_frequency.csv")
df_test.drop(columns=["Unnamed: 0"],inplace=True)

# %%
x_test = df_test.iloc[:,1:].values
y_test = df_test.iloc[:,0].values

# %%
var_pca = [i/100 for i in range(90,101)]
res_timerun = []

# %%
for var in var_pca:
    scale = MinMaxScaler()
    x_train_sc = scale.fit_transform(x_train)

    pca = PCA(n_components=var)
    x_train_pca = pca.fit_transform(x_train_sc)
    d_train = x_train_pca.shape[1]

    x_test_sc = scale.transform(x_test)
    x_test_pca = pca.transform(x_test_sc)

    import time
    start_time = time.perf_counter()

    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.model_selection import GridSearchCV
    model = KNeighborsClassifier()
    params = {
        'n_neighbors': [8,10,12],
        'weights': ['uniform'],
        'algorithm': ['auto'],
        'p': [1,2,3]
    }
    grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
    grid_model = grid_search.fit(x_train_pca,y_train)

    end_time = time.perf_counter()
    res_etime = end_time - start_time
    res_timerun.append(res_etime)
    
    result_test = grid_model.predict(x_test_pca)
    result_train = grid_model.predict_proba(x_train_pca)
    from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,multilabel_confusion_matrix,f1_score,precision_score,accuracy_score,recall_score,precision_recall_fscore_support
    def evaluation_test(y,y_pred, time):
        cm = confusion_matrix(y,y_pred)
        disp = ConfusionMatrixDisplay(cm,display_labels=['AFIB','SB','SR','GSVT'])
        disp.plot()
        plt.show()
        n_classes = len(cm)
        class_counts = np.sum(cm, axis=1)
        result = []
        specificities = []
        weights = class_counts / np.sum(class_counts) 
        for c in range(n_classes):
            tp = cm[c,c]
            fp = sum(cm[:,c]) - cm[c,c]
            fn = sum(cm[c,:]) - cm[c,c]
            tn = sum(np.delete(sum(cm)-cm[c,:],c))
            acc = (tp+tn) / (tp+fn+tn+fp)
            recall = tp/(tp+fn)
            precision = tp/(tp+fp)
            specificity = tn/(tn+fp)
            specificities.append(specificity)
            f1_score = 2*((precision*recall)/(precision+recall))
            if c+1 == 1:
                Rhythm = 'AFIB'
            elif c+1 == 2:
                Rhythm = 'SB'
            elif c+1 == 3:
                Rhythm = 'SR'
            else:
                Rhythm = 'GSVT'
            result.append([Rhythm,acc,recall,precision,f1_score,specificity])
        p_macro,r_macro,f_macro,support_macro = precision_recall_fscore_support(y,y_pred,average='macro')
        p_micro,r_micro,f_micro,support_micro = precision_recall_fscore_support(y,y_pred,average='micro')
        p_weighted,r_weighted,f_weighted,support_weighted = precision_recall_fscore_support(y,y_pred,average='weighted')

        s_marco = np.mean(specificities)
        tn_total = np.sum([np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1)) for i in range(n_classes)])
        fp_total = np.sum([np.sum(cm[:, i]) - cm[i, i] for i in range(n_classes)])
        s_mirco = tn_total / (tn_total + fp_total)
        s_weighted = np.sum(weights * specificities)

        result.append(['macro avg',None,f_macro,p_macro,r_macro,s_marco])
        result.append(['micro avg',None,f_micro,p_micro,r_micro,s_mirco])
        result.append(['weighted avg',None,f_weighted,p_weighted,r_weighted,s_weighted, d_train, time])
        return result
    evaluation_test = evaluation_test(y_test, result_test, res_etime)
    df_evaluation_test = pd.DataFrame(data=evaluation_test,columns=["Rhythm Group","ACC","F1-score","Precision","Recall","specificity","Feature", "Time"])
    var_text = str(var).replace('.','_')
    df_evaluation_test.to_csv(f"./Result_full/KNN_{var_text}.csv")
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.924, test=0.906) total time=   0.2s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.922, test=0.912) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.929, test=0.901) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.926, test=0.915) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.927, test=0.911) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.928, test=0.909) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.923, test=0.909) total time=   3.3s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.924, test=0.911) total time=   3.4s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.929, test=0.907) total time=   3.6s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.922, test=0.908) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.922, test=0.908) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.925, test=0.904) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.924, test=0.919) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.924, test=0.912) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.928, test=0.907) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.922, test=0.913) total time=   3.5s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.924, test=0.912) total time=   3.6s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.928, test=0.907) total time=   3.8s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.921, test=0.911) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.921, test=0.910) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.924, test=0.906) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.922, test=0.919) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.923, test=0.915) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.928, test=0.907) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.919, test=0.918) total time=   3.5s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.921, test=0.913) total time=   3.5s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.926, test=0.909) total time=   3.5s
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.925, test=0.908) total time=   0.1s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.923, test=0.909) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.927, test=0.901) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.925, test=0.917) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.927, test=0.912) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.928, test=0.904) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.924, test=0.911) total time=   3.9s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.924, test=0.912) total time=   3.8s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.928, test=0.904) total time=   4.0s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.922, test=0.909) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.919, test=0.912) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.925, test=0.902) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.923, test=0.920) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.924, test=0.914) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.928, test=0.906) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.922, test=0.914) total time=   3.9s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.922, test=0.911) total time=   3.7s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.926, test=0.910) total time=   3.9s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.921, test=0.909) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.917, test=0.911) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.922, test=0.903) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.922, test=0.919) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.922, test=0.913) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.928, test=0.905) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.921, test=0.917) total time=   4.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.919, test=0.913) total time=   3.7s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.925, test=0.907) total time=   3.7s
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.924, test=0.910) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.923, test=0.905) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.927, test=0.898) total time=   0.1s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.925, test=0.916) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.924, test=0.911) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.928, test=0.906) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.923, test=0.912) total time=   4.2s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.922, test=0.911) total time=   4.2s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.927, test=0.904) total time=   4.1s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.923, test=0.910) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.919, test=0.907) total time=   0.1s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.923, test=0.900) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.920, test=0.919) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.922, test=0.914) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.927, test=0.905) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.922, test=0.913) total time=   4.1s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.923, test=0.912) total time=   4.0s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.925, test=0.908) total time=   3.9s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.919, test=0.907) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.917, test=0.907) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.922, test=0.901) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.919, test=0.916) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.921, test=0.913) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.927, test=0.907) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.920, test=0.916) total time=   3.9s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.921, test=0.913) total time=   4.2s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.924, test=0.908) total time=   4.1s
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.923, test=0.906) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.922, test=0.911) total time=   0.1s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.924, test=0.898) total time=   0.1s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.926, test=0.914) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.925, test=0.915) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.927, test=0.905) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.924, test=0.911) total time=   4.4s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.924, test=0.911) total time=   4.3s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.928, test=0.905) total time=   4.4s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.921, test=0.909) total time=   0.1s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.919, test=0.913) total time=   0.1s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.924, test=0.902) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.922, test=0.918) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.922, test=0.913) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.927, test=0.905) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.921, test=0.913) total time=   4.3s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.921, test=0.911) total time=   4.4s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.927, test=0.908) total time=   4.3s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.920, test=0.910) total time=   0.1s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.917, test=0.912) total time=   0.1s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.920, test=0.900) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.922, test=0.920) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.921, test=0.914) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.924, test=0.908) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.921, test=0.915) total time=   4.3s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.921, test=0.914) total time=   4.3s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.924, test=0.908) total time=   4.3s
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.925, test=0.907) total time=   0.1s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.921, test=0.908) total time=   0.1s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.922, test=0.894) total time=   0.1s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.925, test=0.917) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.926, test=0.911) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.928, test=0.905) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.924, test=0.910) total time=   4.8s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.924, test=0.910) total time=   5.1s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.929, test=0.905) total time=   5.1s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.922, test=0.908) total time=   0.1s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.918, test=0.912) total time=   0.1s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.920, test=0.898) total time=   0.1s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.922, test=0.917) total time=   0.1s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.923, test=0.910) total time=   0.1s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.925, test=0.906) total time=   0.1s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.921, test=0.913) total time=   5.4s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.922, test=0.912) total time=   5.2s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.926, test=0.909) total time=   5.1s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.921, test=0.908) total time=   0.1s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.915, test=0.910) total time=   0.1s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.917, test=0.900) total time=   0.1s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.922, test=0.917) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.922, test=0.913) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.925, test=0.909) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.920, test=0.914) total time=   4.9s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.921, test=0.912) total time=   6.6s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.923, test=0.909) total time=   5.5s
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.924, test=0.904) total time=   0.1s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.919, test=0.909) total time=   0.1s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.920, test=0.891) total time=   0.1s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.924, test=0.914) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.926, test=0.911) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.927, test=0.901) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.924, test=0.909) total time=   6.0s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.924, test=0.910) total time=   6.1s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.928, test=0.906) total time=   5.9s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.922, test=0.906) total time=   0.1s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.917, test=0.906) total time=   0.2s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.919, test=0.897) total time=   0.1s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.921, test=0.918) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.922, test=0.910) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.925, test=0.908) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.921, test=0.912) total time=   7.1s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.922, test=0.912) total time=   6.1s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.926, test=0.910) total time=   8.2s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.920, test=0.907) total time=   0.1s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.916, test=0.909) total time=   0.1s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.917, test=0.897) total time=   0.1s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.922, test=0.917) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.920, test=0.912) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.925, test=0.909) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.919, test=0.914) total time=   6.7s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.920, test=0.911) total time=   6.5s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.924, test=0.910) total time=   6.2s
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.922, test=0.899) total time=   0.1s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.919, test=0.906) total time=   0.1s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.918, test=0.891) total time=   0.1s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.924, test=0.913) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.924, test=0.908) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.928, test=0.902) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.924, test=0.910) total time=   7.0s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.923, test=0.910) total time=   7.1s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.930, test=0.904) total time=   6.7s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.920, test=0.905) total time=   0.1s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.918, test=0.907) total time=   0.2s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.918, test=0.893) total time=   0.1s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.922, test=0.917) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.923, test=0.910) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.925, test=0.908) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.920, test=0.912) total time=   7.0s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.922, test=0.911) total time=   7.6s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.927, test=0.909) total time=   7.1s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.920, test=0.904) total time=   0.1s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.917, test=0.907) total time=   0.1s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.916, test=0.891) total time=   0.1s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.920, test=0.917) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.920, test=0.913) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.923, test=0.910) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.918, test=0.915) total time=   6.7s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.921, test=0.911) total time=   6.7s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.924, test=0.908) total time=   6.5s
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.923, test=0.900) total time=   0.2s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.920, test=0.906) total time=   0.1s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.919, test=0.890) total time=   0.1s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.923, test=0.915) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.925, test=0.908) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.929, test=0.900) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.925, test=0.911) total time=   7.7s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.923, test=0.909) total time=   7.7s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.929, test=0.903) total time=   7.4s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.920, test=0.900) total time=   0.1s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.917, test=0.905) total time=   0.1s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.918, test=0.889) total time=   0.2s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.922, test=0.917) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.922, test=0.911) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.925, test=0.906) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.921, test=0.911) total time=   7.8s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.922, test=0.912) total time=   8.4s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.927, test=0.910) total time=   7.4s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.919, test=0.904) total time=   0.1s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.913, test=0.907) total time=   0.2s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.915, test=0.891) total time=   0.1s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.921, test=0.918) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.920, test=0.911) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.921, test=0.908) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.918, test=0.914) total time=   8.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.920, test=0.912) total time=   7.8s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.923, test=0.909) total time=   7.6s
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.924, test=0.900) total time=   0.2s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.917, test=0.905) total time=   0.2s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.918, test=0.889) total time=   0.2s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.925, test=0.914) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.925, test=0.910) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.930, test=0.902) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.924, test=0.911) total time=   8.9s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.924, test=0.908) total time=   8.9s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.929, test=0.904) total time=   8.5s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.919, test=0.901) total time=   0.2s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.913, test=0.905) total time=   0.2s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.917, test=0.887) total time=   0.2s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.923, test=0.918) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.922, test=0.911) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.925, test=0.907) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.920, test=0.912) total time=   9.1s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.922, test=0.911) total time=   8.5s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.927, test=0.909) total time=   9.2s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.918, test=0.902) total time=   0.2s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.914, test=0.902) total time=   0.2s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.912, test=0.885) total time=   0.2s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.920, test=0.918) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.921, test=0.912) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.921, test=0.905) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.917, test=0.914) total time=   8.6s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.921, test=0.911) total time=   9.1s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.922, test=0.908) total time=   9.1s
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.920, test=0.903) total time=   0.3s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.915, test=0.901) total time=   0.3s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.917, test=0.887) total time=   0.3s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.924, test=0.912) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.925, test=0.910) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.927, test=0.902) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.923, test=0.911) total time=  11.4s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.923, test=0.907) total time=  12.3s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.929, test=0.905) total time=  13.9s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.918, test=0.900) total time=   0.3s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.912, test=0.902) total time=   0.4s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.915, test=0.888) total time=   0.5s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.923, test=0.917) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.922, test=0.911) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.925, test=0.904) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.920, test=0.911) total time=  15.5s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.923, test=0.911) total time=  14.4s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.926, test=0.908) total time=  15.3s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.915, test=0.902) total time=   0.3s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.912, test=0.903) total time=   0.2s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.910, test=0.885) total time=   0.2s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.920, test=0.918) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.921, test=0.911) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.921, test=0.906) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.917, test=0.916) total time=  15.5s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.921, test=0.912) total time=  14.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.922, test=0.908) total time=  13.8s
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[7], line 6
#       3 x_train_sc = scale.fit_transform(x_train)
#       5 pca = PCA(n_components=var)
# ----> 6 x_train_pca = pca.fit_transform(x_train_sc)
#       7 d_train = x_train_pca.shape[1]
#       9 x_test_sc = scale.transform(x_test)
#
# File c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\base.py:1466, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1461 partial_fit_and_fitted = (
#    1462     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1463 )
#    1465 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
#    1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\base.py:666, in BaseEstimator._validate_params(self)
#     658 def _validate_params(self):
#     659     """Validate types and values of constructor parameters
#     660
#     661     The expected type and values must be defined in the `_parameter_constraints`
#    (...)
#     664     accepted constraints.
#     665     """
# --> 666     validate_parameter_constraints(
#     667         self._parameter_constraints,
#     668         self.get_params(deep=False),
#     669         caller_name=self.__class__.__name__,
#     670     )
#
# File c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\utils\_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      89 else:
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'n_components' parameter of PCA must be an int in the range [0, inf), a float in the range (0.0, 1.0), a str among {'mle'} or None. Got 1.0 instead.

# %%
scale = MinMaxScaler()
x_train_sc = scale.fit_transform(x_train)

pca = PCA(n_components=None)
x_train_pca = pca.fit_transform(x_train_sc)
d_train = x_train_pca.shape[1]

x_test_sc = scale.transform(x_test)
x_test_pca = pca.transform(x_test_sc)

import time
start_time = time.perf_counter()

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
model = KNeighborsClassifier()
params = {
    'n_neighbors': [8,10,12],
    'weights': ['uniform'],
    'algorithm': ['auto'],
    'p': [1,2,3]
}
grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
grid_model = grid_search.fit(x_train_pca,y_train)

end_time = time.perf_counter()
res_etime = end_time - start_time
res_timerun.append(res_etime)

result_test = grid_model.predict(x_test_pca)
result_train = grid_model.predict_proba(x_train_pca)
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,multilabel_confusion_matrix,f1_score,precision_score,accuracy_score,recall_score,precision_recall_fscore_support
def evaluation_test(y,y_pred, time):
    cm = confusion_matrix(y,y_pred)
    disp = ConfusionMatrixDisplay(cm,display_labels=['AFIB','SB','SR','GSVT'])
    disp.plot()
    plt.show()
    n_classes = len(cm)
    class_counts = np.sum(cm, axis=1)
    result = []
    specificities = []
    weights = class_counts / np.sum(class_counts) 
    for c in range(n_classes):
        tp = cm[c,c]
        fp = sum(cm[:,c]) - cm[c,c]
        fn = sum(cm[c,:]) - cm[c,c]
        tn = sum(np.delete(sum(cm)-cm[c,:],c))
        acc = (tp+tn) / (tp+fn+tn+fp)
        recall = tp/(tp+fn)
        precision = tp/(tp+fp)
        specificity = tn/(tn+fp)
        specificities.append(specificity)
        f1_score = 2*((precision*recall)/(precision+recall))
        if c+1 == 1:
            Rhythm = 'AFIB'
        elif c+1 == 2:
            Rhythm = 'SB'
        elif c+1 == 3:
            Rhythm = 'SR'
        else:
            Rhythm = 'GSVT'
        result.append([Rhythm,acc,recall,precision,f1_score,specificity])
    p_macro,r_macro,f_macro,support_macro = precision_recall_fscore_support(y,y_pred,average='macro')
    p_micro,r_micro,f_micro,support_micro = precision_recall_fscore_support(y,y_pred,average='micro')
    p_weighted,r_weighted,f_weighted,support_weighted = precision_recall_fscore_support(y,y_pred,average='weighted')

    s_marco = np.mean(specificities)
    tn_total = np.sum([np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1)) for i in range(n_classes)])
    fp_total = np.sum([np.sum(cm[:, i]) - cm[i, i] for i in range(n_classes)])
    s_mirco = tn_total / (tn_total + fp_total)
    s_weighted = np.sum(weights * specificities)

    result.append(['macro avg',None,f_macro,p_macro,r_macro,s_marco])
    result.append(['micro avg',None,f_micro,p_micro,r_micro,s_mirco])
    result.append(['weighted avg',None,f_weighted,p_weighted,r_weighted,s_weighted, d_train, time])
    return result
evaluation_test = evaluation_test(y_test, result_test, res_etime)
df_evaluation_test = pd.DataFrame(data=evaluation_test,columns=["Rhythm Group","ACC","F1-score","Precision","Recall","specificity","Feature", "Time"])
df_evaluation_test.to_csv(f"./Result/KNN_0_100.csv")
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.917, test=0.899) total time=   0.2s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.914, test=0.895) total time=   0.2s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=1, weights=uniform;, score=(train=0.913, test=0.880) total time=   0.2s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.924, test=0.912) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.925, test=0.909) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=2, weights=uniform;, score=(train=0.927, test=0.901) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.923, test=0.912) total time=   9.7s
# [CV 2/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.923, test=0.906) total time=   9.7s
# [CV 3/3] END algorithm=auto, n_neighbors=8, p=3, weights=uniform;, score=(train=0.930, test=0.905) total time=   9.6s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.916, test=0.900) total time=   0.2s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.910, test=0.898) total time=   0.2s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=1, weights=uniform;, score=(train=0.907, test=0.879) total time=   0.2s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.922, test=0.917) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.922, test=0.910) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=2, weights=uniform;, score=(train=0.924, test=0.904) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.919, test=0.910) total time=   9.7s
# [CV 2/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.923, test=0.909) total time=   9.8s
# [CV 3/3] END algorithm=auto, n_neighbors=10, p=3, weights=uniform;, score=(train=0.926, test=0.907) total time=   9.7s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.913, test=0.895) total time=   0.2s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.906, test=0.897) total time=   0.3s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=1, weights=uniform;, score=(train=0.904, test=0.878) total time=   0.2s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.920, test=0.919) total time=   0.0s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.921, test=0.909) total time=   0.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=2, weights=uniform;, score=(train=0.921, test=0.906) total time=   0.0s
# [CV 1/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.918, test=0.915) total time=  10.1s
# [CV 2/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.921, test=0.911) total time=  10.0s
# [CV 3/3] END algorithm=auto, n_neighbors=12, p=3, weights=uniform;, score=(train=0.923, test=0.909) total time=  10.3s

# %% [markdown]
# 0.99 -> 138
# 0.98 -> 116
# 0.96 -> 90
# 0.95 -> 81
# 0.90 -> 51
