# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# %%
df_train = pd.read_csv("./dataset/data_train_frequency.csv")
df_train.drop(columns=["Unnamed: 0"],inplace=True)

# %%
x_train = df_train.iloc[:,1:].values
y_train = df_train.iloc[:,0].values

# %%
df_test = pd.read_csv("./dataset/data_test_frequency.csv")
df_test.drop(columns=["Unnamed: 0"],inplace=True)

# %%
x_test = df_test.iloc[:,1:].values
y_test = df_test.iloc[:,0].values

# %%
var_pca = [i/100 for i in range(90,101)]
res_timerun = []

# %%
for var in var_pca:
    scale = MinMaxScaler()
    x_train_sc = scale.fit_transform(x_train)

    pca = PCA(n_components=var)
    x_train_pca = pca.fit_transform(x_train_sc)
    d_train = x_train_pca.shape[1]

    x_test_sc = scale.transform(x_test)
    x_test_pca = pca.transform(x_test_sc)

    import time
    start_time = time.perf_counter()

    from sklearn.tree import DecisionTreeClassifier
    from sklearn.model_selection import GridSearchCV
    model = DecisionTreeClassifier()
    params = {
        'criterion':['gini', 'entropy'],
        'max_depth': [4,5,6],
        'splitter':['best', 'random'],
        'max_features':['auto', 'sqrt', 'log2']
    }
    grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
    grid_model = grid_search.fit(x_train_pca,y_train)

    end_time = time.perf_counter()
    res_etime = end_time - start_time
    res_timerun.append(res_etime)
    
    result_test = grid_model.predict(x_test_pca)
    result_train = grid_model.predict_proba(x_train_pca)
    from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,multilabel_confusion_matrix,f1_score,precision_score,accuracy_score,recall_score,precision_recall_fscore_support
    def evaluation_test(y,y_pred, time):
        cm = confusion_matrix(y,y_pred)
        disp = ConfusionMatrixDisplay(cm,display_labels=['AFIB','SB','SR','GSVT'])
        disp.plot()
        plt.show()
        n_classes = len(cm)
        class_counts = np.sum(cm, axis=1)
        result = []
        specificities = []
        weights = class_counts / np.sum(class_counts) 
        for c in range(n_classes):
            tp = cm[c,c]
            fp = sum(cm[:,c]) - cm[c,c]
            fn = sum(cm[c,:]) - cm[c,c]
            tn = sum(np.delete(sum(cm)-cm[c,:],c))
            acc = (tp+tn) / (tp+fn+tn+fp)
            recall = tp/(tp+fn)
            precision = tp/(tp+fp)
            specificity = tn/(tn+fp)
            specificities.append(specificity)
            f1_score = 2*((precision*recall)/(precision+recall))
            if c+1 == 1:
                Rhythm = 'AFIB'
            elif c+1 == 2:
                Rhythm = 'SB'
            elif c+1 == 3:
                Rhythm = 'SR'
            else:
                Rhythm = 'GSVT'
            result.append([Rhythm,acc,recall,precision,f1_score,specificity])
        p_macro,r_macro,f_macro,support_macro = precision_recall_fscore_support(y,y_pred,average='macro')
        p_micro,r_micro,f_micro,support_micro = precision_recall_fscore_support(y,y_pred,average='micro')
        p_weighted,r_weighted,f_weighted,support_weighted = precision_recall_fscore_support(y,y_pred,average='weighted')

        s_marco = np.mean(specificities)
        tn_total = np.sum([np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1)) for i in range(n_classes)])
        fp_total = np.sum([np.sum(cm[:, i]) - cm[i, i] for i in range(n_classes)])
        s_mirco = tn_total / (tn_total + fp_total)
        s_weighted = np.sum(weights * specificities)

        result.append(['macro avg',None,f_macro,p_macro,r_macro,s_marco])
        result.append(['micro avg',None,f_micro,p_micro,r_micro,s_mirco])
        result.append(['weighted avg',None,f_weighted,p_weighted,r_weighted,s_weighted, d_train, time])
        return result
    evaluation_test = evaluation_test(y_test, result_test, res_etime)
    df_evaluation_test = pd.DataFrame(data=evaluation_test,columns=["Rhythm Group","ACC","F1-score","Precision","Recall","specificity","Feature", "Time"])
    var_text = str(var).replace('.','_')
    df_evaluation_test.to_csv(f"./Result_full/DT_{var_text}.csv")
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV 1/3] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.683, test=0.653) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.737, test=0.723) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.647, test=0.635) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.408, test=0.403) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.424, test=0.423) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.502, test=0.499) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=(train=0.685, test=0.688) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=(train=0.541, test=0.534) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=(train=0.626, test=0.609) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=(train=0.389, test=0.386) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=(train=0.391, test=0.390) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=(train=0.434, test=0.437) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.702, test=0.693) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.734, test=0.722) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.643, test=0.616) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.452, test=0.450) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.520, test=0.526) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.409, test=0.409) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.586, test=0.563) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.744, test=0.737) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.853, test=0.825) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.551, test=0.553) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.420, test=0.405) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.572, test=0.557) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.871, test=0.852) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.878, test=0.850) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.706, test=0.666) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.468, test=0.474) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.531, test=0.520) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.424, test=0.408) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=log2, splitter=best;, score=(train=0.809, test=0.796) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=log2, splitter=best;, score=(train=0.892, test=0.872) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=log2, splitter=best;, score=(train=0.688, test=0.655) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=log2, splitter=random;, score=(train=0.403, test=0.398) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=log2, splitter=random;, score=(train=0.463, test=0.454) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=log2, splitter=random;, score=(train=0.619, test=0.615) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.742, test=0.732) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.676, test=0.667) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.845, test=0.829) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.458, test=0.458) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.423, test=0.411) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.414, test=0.411) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.583, test=0.575) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.451, test=0.443) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.430, test=0.411) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.395, test=0.395) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.448, test=0.444) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.430, test=0.436) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.672, test=0.652) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.755, test=0.741) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.538, test=0.518) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.424, test=0.419) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.608, test=0.601) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.426, test=0.417) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.877, test=0.877) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.698, test=0.683) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.569, test=0.544) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.415, test=0.409) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.426, test=0.422) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.419, test=0.416) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.651, test=0.615) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.829, test=0.816) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.671, test=0.631) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.512, test=0.496) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.426, test=0.412) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.535, test=0.516) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=best;, score=(train=0.897, test=0.876) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=best;, score=(train=0.758, test=0.747) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=best;, score=(train=0.632, test=0.597) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=random;, score=(train=0.562, test=0.563) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=random;, score=(train=0.439, test=0.430) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=random;, score=(train=0.575, test=0.569) total time=   0.0s
# c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 36 fits failed out of a total of 108.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 36 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\model_selection\_search.py:1103: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.67026363 0.44164604 0.61026287 0.40418425
#         nan        nan 0.67695385 0.46171298 0.70809258 0.50517284
#         nan        nan 0.78932327 0.46758343 0.77429314 0.4889767
#         nan        nan 0.74261236 0.42684175 0.47650713 0.42484864
#         nan        nan 0.63725705 0.47885603 0.70136715 0.41568817
#         nan        nan 0.68717049 0.47464082 0.73988453 0.5206727 ]
#   warnings.warn(
# c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\model_selection\_search.py:1103: UserWarning: One or more of the train scores are non-finite: [       nan        nan 0.68905837 0.44463027 0.61736683 0.40482451
#         nan        nan 0.69311003 0.46007817 0.727623   0.51426388
#         nan        nan 0.81834854 0.47440408 0.79621349 0.49482599
#         nan        nan 0.75439816 0.43183522 0.4877911  0.42414245
#         nan        nan 0.65500922 0.48602981 0.7144872  0.42026779
#         nan        nan 0.71718213 0.49095561 0.76227865 0.52530238]
#   warnings.warn(
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV 1/3] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.740, test=0.732) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.731, test=0.722) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.719, test=0.686) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.413, test=0.410) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.431, test=0.425) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.396, test=0.400) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=(train=0.446, test=0.429) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=(train=0.722, test=0.721) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=(train=0.582, test=0.558) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=(train=0.522, test=0.522) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=(train=0.394, test=0.389) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=(train=0.567, test=0.559) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.520, test=0.488) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.706, test=0.682) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.893, test=0.859) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.544, test=0.540) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.760, test=0.752) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.456, test=0.454) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.600, test=0.587) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.649, test=0.613) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.667, test=0.632) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.405, test=0.402) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.442, test=0.425) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.410, test=0.402) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.700, test=0.678) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.613, test=0.571) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.670, test=0.611) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.419, test=0.413) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.483, test=0.464) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.477, test=0.463) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=log2, splitter=best;, score=(train=0.776, test=0.729) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=log2, splitter=best;, score=(train=0.822, test=0.800) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=log2, splitter=best;, score=(train=0.586, test=0.549) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=log2, splitter=random;, score=(train=0.431, test=0.431) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=log2, splitter=random;, score=(train=0.594, test=0.600) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=log2, splitter=random;, score=(train=0.501, test=0.484) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.672, test=0.677) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.643, test=0.628) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.662, test=0.653) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.405, test=0.403) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.516, test=0.513) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.434, test=0.442) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.493, test=0.476) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.733, test=0.736) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.527, test=0.518) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.586, test=0.582) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.431, test=0.424) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.441, test=0.437) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.768, test=0.743) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.685, test=0.664) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.784, test=0.745) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.464, test=0.474) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.412, test=0.406) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.418, test=0.401) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.614, test=0.591) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.580, test=0.578) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.508, test=0.471) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.398, test=0.394) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.436, test=0.429) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.571, test=0.565) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.617, test=0.595) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.815, test=0.784) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.744, test=0.700) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.417, test=0.408) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.491, test=0.487) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.429, test=0.420) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=best;, score=(train=0.615, test=0.586) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=best;, score=(train=0.795, test=0.760) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=best;, score=(train=0.716, test=0.678) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=random;, score=(train=0.552, test=0.539) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=random;, score=(train=0.397, test=0.381) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=random;, score=(train=0.427, test=0.426) total time=   0.0s
# c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 36 fits failed out of a total of 108.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 36 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\model_selection\_search.py:1103: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.71347724 0.4118117  0.56928    0.48979204
#         nan        nan 0.67627796 0.58194836 0.61073525 0.40969845
#         nan        nan 0.62012579 0.44680796 0.69279668 0.50504691
#         nan        nan 0.65288868 0.45267608 0.57690716 0.48108922
#         nan        nan 0.71724135 0.42719283 0.54660926 0.46278798
#         nan        nan 0.6929318  0.43846664 0.6747303  0.44856471]
#   warnings.warn(
# c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\model_selection\_search.py:1103: UserWarning: One or more of the train scores are non-finite: [       nan        nan 0.7299795  0.41345803 0.58331387 0.49412441
#         nan        nan 0.70660014 0.58672679 0.63856106 0.41891783
#         nan        nan 0.66104927 0.45972189 0.72799097 0.50833769
#         nan        nan 0.65893596 0.45144539 0.58437396 0.48591152
#         nan        nan 0.74582911 0.43124783 0.56699501 0.4684651
#         nan        nan 0.72545689 0.445574   0.70890048 0.45837434]
#   warnings.warn(
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV 1/3] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.581, test=0.568) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.676, test=0.652) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.645, test=0.610) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.491, test=0.501) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.396, test=0.393) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.554, test=0.550) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=(train=0.631, test=0.620) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=(train=0.549, test=0.549) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=(train=0.621, test=0.603) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=(train=0.665, test=0.668) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=(train=0.384, test=0.381) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=(train=0.400, test=0.384) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.767, test=0.745) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.720, test=0.697) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.711, test=0.698) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.520, test=0.517) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.523, test=0.509) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.451, test=0.438) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.593, test=0.583) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.630, test=0.614) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.760, test=0.732) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.388, test=0.383) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.448, test=0.446) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.394, test=0.384) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.842, test=0.813) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.612, test=0.580) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.767, test=0.727) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.425, test=0.415) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.566, test=0.556) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.775, test=0.759) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=log2, splitter=best;, score=(train=0.502, test=0.468) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=log2, splitter=best;, score=(train=0.659, test=0.625) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=log2, splitter=best;, score=(train=0.671, test=0.641) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=log2, splitter=random;, score=(train=0.441, test=0.444) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=log2, splitter=random;, score=(train=0.614, test=0.617) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=log2, splitter=random;, score=(train=0.422, test=0.412) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.753, test=0.751) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.598, test=0.596) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.674, test=0.643) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.423, test=0.425) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.404, test=0.396) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.390, test=0.389) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.549, test=0.521) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.672, test=0.666) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.729, test=0.715) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.429, test=0.433) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.549, test=0.552) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.386, test=0.388) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.558, test=0.536) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.797, test=0.790) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.751, test=0.713) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.472, test=0.475) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.447, test=0.443) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.557, test=0.554) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.668, test=0.653) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.585, test=0.584) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.675, test=0.641) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.407, test=0.405) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.621, test=0.617) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.420, test=0.405) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.790, test=0.776) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.757, test=0.718) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.595, test=0.548) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.419, test=0.413) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.435, test=0.426) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.576, test=0.572) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=best;, score=(train=0.649, test=0.620) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=best;, score=(train=0.556, test=0.525) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=best;, score=(train=0.726, test=0.654) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=random;, score=(train=0.437, test=0.428) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=random;, score=(train=0.545, test=0.524) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=random;, score=(train=0.542, test=0.537) total time=   0.0s
# c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 36 fits failed out of a total of 108.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 36 fits failed with the following error:
# Traceback (most recent call last):
# ...
# [CV 2/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.402, test=0.384) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.423, test=0.411) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.561, test=0.531) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.471, test=0.434) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.555, test=0.523) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.386, test=0.390) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.444, test=0.434) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.421, test=0.431) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.714, test=0.678) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.566, test=0.518) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.754, test=0.698) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.437, test=0.439) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.400, test=0.379) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.414, test=0.405) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=log2, splitter=best;, score=(train=0.639, test=0.626) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=log2, splitter=best;, score=(train=0.606, test=0.596) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=log2, splitter=best;, score=(train=0.618, test=0.571) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=log2, splitter=random;, score=(train=0.418, test=0.397) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=log2, splitter=random;, score=(train=0.410, test=0.403) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=log2, splitter=random;, score=(train=0.398, test=0.390) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.445, test=0.420) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.544, test=0.520) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.557, test=0.541) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.380, test=0.381) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.382, test=0.376) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.423, test=0.415) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.439, test=0.426) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.562, test=0.540) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.415, test=0.397) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.386, test=0.373) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.411, test=0.411) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.380, test=0.375) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.759, test=0.744) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.686, test=0.670) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.541, test=0.508) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.664, test=0.653) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.421, test=0.419) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.523, test=0.509) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.448, test=0.435) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.492, test=0.477) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.664, test=0.617) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.400, test=0.402) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.407, test=0.395) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.397, test=0.384) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.847, test=0.825) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.783, test=0.761) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.604, test=0.567) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.432, test=0.431) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.473, test=0.448) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.418, test=0.408) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=best;, score=(train=0.516, test=0.492) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=best;, score=(train=0.518, test=0.485) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=best;, score=(train=0.507, test=0.467) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=random;, score=(train=0.413, test=0.408) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=random;, score=(train=0.504, test=0.498) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=random;, score=(train=0.411, test=0.402) total time=   0.0s
# c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 36 fits failed out of a total of 108.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 36 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\model_selection\_search.py:1103: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.433773   0.39408159 0.44681176 0.40570639
#         nan        nan 0.52559591 0.39056129 0.4958933  0.41827293
#         nan        nan 0.63140754 0.40758544 0.59757792 0.39666428
#         nan        nan 0.49319485 0.39079665 0.45431456 0.38633031
#         nan        nan 0.64066085 0.5271233  0.5096415  0.39384577
#         nan        nan 0.71769018 0.42907225 0.48144498 0.43599879]
#   warnings.warn(
# c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\model_selection\_search.py:1103: UserWarning: One or more of the train scores are non-finite: [       nan        nan 0.45191289 0.39936557 0.46382984 0.4110498
#         nan        nan 0.54732377 0.40241776 0.52888528 0.41709701
#         nan        nan 0.67818951 0.41698    0.62094897 0.40881931
#         nan        nan 0.51520424 0.39472594 0.47182109 0.39237978
#         nan        nan 0.66211374 0.53622671 0.53492663 0.40112755
#         nan        nan 0.74472409 0.44093608 0.51373922 0.4428741 ]
#   warnings.warn(
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[7], line 6
#       3 x_train_sc = scale.fit_transform(x_train)
#       5 pca = PCA(n_components=var)
# ----> 6 x_train_pca = pca.fit_transform(x_train_sc)
#       7 d_train = x_train_pca.shape[1]
#       9 x_test_sc = scale.transform(x_test)
#
# File c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\base.py:1466, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1461 partial_fit_and_fitted = (
#    1462     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1463 )
#    1465 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
#    1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\base.py:666, in BaseEstimator._validate_params(self)
#     658 def _validate_params(self):
#     659     """Validate types and values of constructor parameters
#     660
#     661     The expected type and values must be defined in the `_parameter_constraints`
#    (...)
#     664     accepted constraints.
#     665     """
# --> 666     validate_parameter_constraints(
#     667         self._parameter_constraints,
#     668         self.get_params(deep=False),
#     669         caller_name=self.__class__.__name__,
#     670     )
#
# File c:\Users\Admin\anaconda3\envs\testdatasets\lib\site-packages\sklearn\utils\_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      89 else:
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'n_components' parameter of PCA must be an int in the range [0, inf), a float in the range (0.0, 1.0), a str among {'mle'} or None. Got 1.0 instead.

# %%
scale = MinMaxScaler()
x_train_sc = scale.fit_transform(x_train)

pca = PCA(n_components=None)
x_train_pca = pca.fit_transform(x_train_sc)
d_train = x_train_pca.shape[1]

x_test_sc = scale.transform(x_test)
x_test_pca = pca.transform(x_test_sc)

import time
start_time = time.perf_counter()

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
model = DecisionTreeClassifier()
params = {
    'criterion':['gini', 'entropy'],
    'max_depth': [4,5,6],
    'splitter':['best', 'random'],
    'max_features':['auto', 'sqrt', 'log2']
}
grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
grid_model = grid_search.fit(x_train_pca,y_train)

end_time = time.perf_counter()
res_etime = end_time - start_time
res_timerun.append(res_etime)

result_test = grid_model.predict(x_test_pca)
result_train = grid_model.predict_proba(x_train_pca)
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,multilabel_confusion_matrix,f1_score,precision_score,accuracy_score,recall_score,precision_recall_fscore_support
def evaluation_test(y,y_pred, time):
    cm = confusion_matrix(y,y_pred)
    disp = ConfusionMatrixDisplay(cm,display_labels=['AFIB','SB','SR','GSVT'])
    disp.plot()
    plt.show()
    n_classes = len(cm)
    class_counts = np.sum(cm, axis=1)
    result = []
    specificities = []
    weights = class_counts / np.sum(class_counts) 
    for c in range(n_classes):
        tp = cm[c,c]
        fp = sum(cm[:,c]) - cm[c,c]
        fn = sum(cm[c,:]) - cm[c,c]
        tn = sum(np.delete(sum(cm)-cm[c,:],c))
        acc = (tp+tn) / (tp+fn+tn+fp)
        recall = tp/(tp+fn)
        precision = tp/(tp+fp)
        specificity = tn/(tn+fp)
        specificities.append(specificity)
        f1_score = 2*((precision*recall)/(precision+recall))
        if c+1 == 1:
            Rhythm = 'AFIB'
        elif c+1 == 2:
            Rhythm = 'SB'
        elif c+1 == 3:
            Rhythm = 'SR'
        else:
            Rhythm = 'GSVT'
        result.append([Rhythm,acc,recall,precision,f1_score,specificity])
    p_macro,r_macro,f_macro,support_macro = precision_recall_fscore_support(y,y_pred,average='macro')
    p_micro,r_micro,f_micro,support_micro = precision_recall_fscore_support(y,y_pred,average='micro')
    p_weighted,r_weighted,f_weighted,support_weighted = precision_recall_fscore_support(y,y_pred,average='weighted')

    s_marco = np.mean(specificities)
    tn_total = np.sum([np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1)) for i in range(n_classes)])
    fp_total = np.sum([np.sum(cm[:, i]) - cm[i, i] for i in range(n_classes)])
    s_mirco = tn_total / (tn_total + fp_total)
    s_weighted = np.sum(weights * specificities)

    result.append(['macro avg',None,f_macro,p_macro,r_macro,s_marco])
    result.append(['micro avg',None,f_micro,p_micro,r_micro,s_mirco])
    result.append(['weighted avg',None,f_weighted,p_weighted,r_weighted,s_weighted, d_train, time])
    return result
evaluation_test = evaluation_test(y_test, result_test, res_etime)
df_evaluation_test = pd.DataFrame(data=evaluation_test,columns=["Rhythm Group","ACC","F1-score","Precision","Recall","specificity","Feature", "Time"])
df_evaluation_test.to_csv(f"./Result/DT_0_100.csv")
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [CV 1/3] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.596, test=0.588) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.647, test=0.658) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.601, test=0.557) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.408, test=0.409) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.545, test=0.542) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.471, test=0.470) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=(train=0.568, test=0.545) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=(train=0.450, test=0.425) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=(train=0.455, test=0.440) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=(train=0.392, test=0.384) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=(train=0.564, test=0.562) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=(train=0.391, test=0.387) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.481, test=0.446) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.604, test=0.569) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.629, test=0.589) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.413, test=0.419) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.406, test=0.396) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.390, test=0.382) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.439, test=0.384) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.595, test=0.569) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.471, test=0.444) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.385, test=0.368) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.582, test=0.578) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.393, test=0.384) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.577, test=0.535) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.710, test=0.669) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.666, test=0.611) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.551, test=0.539) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.422, test=0.419) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.506, test=0.499) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=log2, splitter=best;, score=(train=0.545, test=0.501) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=log2, splitter=best;, score=(train=0.575, test=0.515) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=log2, splitter=best;, score=(train=0.545, test=0.487) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=6, max_features=log2, splitter=random;, score=(train=0.383, test=0.380) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=6, max_features=log2, splitter=random;, score=(train=0.387, test=0.382) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=6, max_features=log2, splitter=random;, score=(train=0.485, test=0.484) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.476, test=0.469) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.738, test=0.732) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.687, test=0.684) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.406, test=0.403) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.384, test=0.379) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.401, test=0.390) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.400, test=0.391) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.432, test=0.404) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.407, test=0.396) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.382, test=0.377) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.377, test=0.372) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.407, test=0.397) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.477, test=0.444) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.494, test=0.461) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.511, test=0.498) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.611, test=0.622) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.417, test=0.401) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.395, test=0.385) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.455, test=0.433) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.583, test=0.563) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.580, test=0.552) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.398, test=0.390) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.403, test=0.401) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.388, test=0.387) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.740, test=0.714) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.527, test=0.508) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=best;, score=(train=0.502, test=0.462) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.544, test=0.532) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.433, test=0.403) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=sqrt, splitter=random;, score=(train=0.607, test=0.584) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=best;, score=(train=0.761, test=0.732) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=best;, score=(train=0.564, test=0.516) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=best;, score=(train=0.722, test=0.667) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=random;, score=(train=0.508, test=0.474) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=random;, score=(train=0.507, test=0.494) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=6, max_features=log2, splitter=random;, score=(train=0.394, test=0.376) total time=   0.0s
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 36 fits failed out of a total of 108.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 36 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.60062895 0.47393101 0.47005289 0.44433332
#         nan        nan 0.53452962 0.39901166 0.46547418 0.44327628
#         nan        nan 0.60509702 0.48555813 0.50117263 0.41534392
#         nan        nan 0.62835321 0.39079376 0.39689985 0.38187117
#         nan        nan 0.46735911 0.4696942  0.51597419 0.39267194
#         nan        nan 0.56151958 0.50611524 0.63844859 0.44820668]
#   warnings.warn(
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the train scores are non-finite: [       nan        nan 0.61454988 0.47469491 0.49101905 0.44898178
#         nan        nan 0.57127423 0.40324172 0.50193933 0.45315054
#         nan        nan 0.65106767 0.49307111 0.55483856 0.41820885
#         nan        nan 0.63374512 0.39684102 0.41316382 0.38862033
#         nan        nan 0.49395153 0.47434708 0.53945273 0.39643074
#         nan        nan 0.58954251 0.52817759 0.68253642 0.46959112]
#   warnings.warn(

# %% [markdown]
# 0.99 -> 138
# 0.98 -> 116
# 0.96 -> 90
# 0.95 -> 81
# 0.90 -> 51
